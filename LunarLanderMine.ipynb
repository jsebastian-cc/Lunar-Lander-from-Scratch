# %%
import torch

# %%
import gym

# %%
from stable_baselines3 import PPO
import os

# %%
models_dir = "models/PPO"
logdir = "logs"

# %%
if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)

# %%
# Create the environment
env = gym.make('LunarLander-v2')  # continuous: LunarLanderContinuous-v2
env.reset()          # required before you can step the environment

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log = logdir) # AC2 es un Algoritmo de reinforcement learning

TIMESTEP = 10000
model.learn(total_timesteps = TIMESTEP)
'''
episodes = 10

for ep in range(episodes):
    obs = env.reset()
    done = False
    while not done:
        action, _states = model.predict(obs)
        obs, rewards, done, info = env.step(action)
        env.render()
        print(rewards)

env.close()'''
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 89        |
# |    ep_rew_mean        | -204      |
# | time/                 |           |
# |    fps                | 606       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | -0.000195 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -10.6     |
# |    value_loss         | 77.6      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 96.5     |
# |    ep_rew_mean        | -207     |
# | time/                 |          |
# ...

# %%
env.reset()
for step in range(200):
    env.render()
    obs, reward, done, info = env.step(env.action_space.sample())
    #print(reward)
env.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 env.reset()
#       2 for step in range(200):
#       3     env.render()
#
# NameError: name 'env' is not defined
